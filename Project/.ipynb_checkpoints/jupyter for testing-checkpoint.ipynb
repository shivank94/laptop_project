# %%
from platform import python_version

print(python_version())
# Out:
# 3.12.7

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
import sklearn as sk

# %%
sk.__version__
# Out:
# '1.6.1'

# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.0-cp311-cp311-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.8 MB 4.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/10.8 MB 11.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/10.8 MB 19.9 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.8 MB 24.1 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.8 MB 22.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.2/10.8 MB 21.0 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.8 MB 20.6 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.8 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.3/10.8 MB 21.2 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.8 MB 24.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.8 MB 24.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 21.1 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.0
